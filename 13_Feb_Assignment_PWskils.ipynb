# %%
# Q1
'''
When you want to create a custom exception in Python, you need to define a new class that inherits from the built-in 
Exception class or one of its subclasses. This is because the Exception class provides the basic functionality of an 
exception, such as storing information about the error that occurred and allowing you to customize the error message.

By creating a new class that inherits from the Exception class, you can define your own custom behavior for your exception. 
For example, you can define additional attributes or methods to provide more information about the error, or you can 
customize the error message to be more informative or user-friendly.
'''

# %%
# Q2
def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent, exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(BaseException)
# Out:
#  BaseException
#      Exception
#          TypeError
#              FloatOperation
#              MultipartConversionError
#          StopAsyncIteration
#          StopIteration
#          ImportError
#              ModuleNotFoundError
#              ZipImportError
#          OSError
#              ConnectionError
#                  BrokenPipeError
#                  ConnectionAbortedError
#                  ConnectionRefusedError
#                  ConnectionResetError
#                      RemoteDisconnected
#              BlockingIOError
#              ChildProcessError
#              FileExistsError
#              FileNotFoundError
#              IsADirectoryError
#              NotADirectoryError
#              InterruptedError
#                  InterruptedSystemCall
#              PermissionError
#              ProcessLookupError
#              TimeoutError
#              UnsupportedOperation
#              herror
#              gaierror
#              timeout
# ...

# %%
# Q3
'''
The ArithmeticError class is a built-in Python exception class that serves as the base class for all errors that occur 
during arithmetic operations. It is a subclass of the Exception class and a superclass for several more specific 
arithmetic error classes.

Errors defined in ArithmeticError class are:-
i) ZeroDivisionError - Division of a number by zero
ii) OverflowError - When the arithmetical operation exceeds the maximum representable value for a numeric type.
'''
# ZeroDivisionErro
try:
    a , b = 5 , 0
    print(a/b)
except ZeroDivisionError as e:
    print(e)

# OverflowError
try:
    a = 999 ** 10000
    print(a)
except OverflowError as e:
    print(e)
# Out:
# division by zero

# %%
# Q4
'''
The LookupError class is used as a base class for exceptions that are raised when a key or index 
used to access a mapping or sequence is invalid or not found.

Two common subclasses of LookupError are KeyError and IndexError.
i) A KeyError is raised when a dictionary key is not found in the dictionary.
i.e. dict1 = {'apple':1 , 'banana':2}
     print(dict1['grape'])   # KeyError
     
ii) An IndexError, on the other hand, is raised when we try to access an item in a sequence using 
an index that is out of range.
i.e. a = [1,3,4]
     print(a[3])   # IndexError

# %%
# Q5
'''
In Python, an ImportError is raised when a module or package is not found or cannot be imported. 
This can happen for a variety of reasons, such as if the module is not installed, if the module 
is not in the Python search path, or if there are syntax errors in the module.

In Python 3.6 and later, a new exception called ModuleNotFoundError was introduced to specifically 
handle cases where a module or package is not found. It is a subclass of ImportError and is raised 
when a module is not found in any of the specified locations in 'sys.path'.

'''

# %%
# Q6
'''
1.Catch specific exceptions: Instead of catching all exceptions with a generic except block, 
catch specific exceptions using their class names. 
2.Use finally: Use a finally block to ensure that code is executed regardless of whether an 
exception is raised. 
3.Raise exceptions when appropriate: If your code encounters an error or an invalid state, 
raise an appropriate exception. This can help other developers understand what went wrong and 
how to fix it.
4.Use logging to track errors: Use a logging framework such as the logging module to log errors 
and exceptions. This can help you track down issues and debug problems in your code.

'''
